# %% [markdown]
# Compare journies
# ================
#
# Compare the travel time when I cycle home via the A3 vs when I come via Richmond Park.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# See Line Through Circle notebook for a description of these
def lines_cross(x1,x2,y1,y2) -> bool:

    a = x2[0]-x1[0]
    b = y1[0]-y2[0]
    c = x2[1]-x1[1]
    d = y1[1]-y2[1]

    Minv = 1 / (a*d - b*c) * np.array([[d, -b],[-c,a]])
    alpha_beta = Minv @ (y1 - x1)
    
    plt.plot([x1[0], x2[0]], [x1[1], x2[1]])
    plt.plot([y1[0], y2[0]], [y1[1], y2[1]])

    return all((0 <= alpha_beta )& (alpha_beta <= 1))

def get_circle_points(c,r,x1,x2):
    v = x1-x2
    u = (1 / np.sqrt(np.dot(v,v))) * np.array([[0,1],[-1,0]]) @ v

    c1 = c - r * u
    c2 = c + r * u
    
    return c1,c2

def does_line_go_through_circle(c,r,x1,x2):
    y1, y2 = get_circle_points(c,r,x1,x2)
    return lines_cross(x1,x2,y1,y2)

# %%
location_log = pd.read_csv("locations.csv").set_index("time")
location_log
# Out:
#                               entity_id   latitude  longitude
# time
# 2022-05-06 03:15:07.110833  person.gaby  51.409610  -0.280304
# 2022-05-06 03:20:23.946649  person.gaby  51.409616  -0.280316
# 2022-05-06 03:24:58.453512  person.gaby  51.409622  -0.280314
# 2022-05-06 03:30:02.878928  person.gaby  51.409595  -0.280277
# 2022-05-06 03:38:07.624507  person.gaby  51.409629  -0.280312
# ...                                 ...        ...        ...
# 2022-10-23 10:38:46.192274  person.gaby  51.409737  -0.280182
# 2022-10-23 10:43:17.976969  person.gaby  51.409736  -0.280219
# 2022-10-23 10:44:48.313036  person.gaby  51.409736  -0.280214
# 2022-10-23 10:46:18.302846  person.gaby  51.409742  -0.280145
# 2022-10-23 10:49:59.107114  person.gaby  51.409731  -0.280122
#
# [42850 rows x 3 columns]

# %%
LOCATIONS = {
    "imperial": (51.4996119163838, -0.1793120020929193),
    "home": (51.409812979622174, -0.28017411558994054),
    "richmond_park": (51.45393576302114, -0.2572030264957135),
    "A3": (51.446922160476056, -0.22615622806043198),
    
}
RADIUS = 100  # meters

# Latitude: 1 deg = 110.574 km
# Longitude: 1 deg = 111.320*cos(latitude) km
def latlong_vec_to_meters(lat, vec):
    lat = np.reshape(np.array(lat), (-1, 1))
    vec = np.reshape(np.array(vec), (-1, 2))
    
    cos_lat = np.cos(lat * np.pi / 180.0)
    conversion_mat = np.hstack([np.ones_like(vec[:,[0]])*110574, cos_lat * 111320])
    return (conversion_mat * vec).squeeze()

print(latlong_vec_to_meters(51.4996119163838, [1,1]))
print(latlong_vec_to_meters([51.4996119163838, 51.4996119163838], [[1,1], [0.5,0.5]]))
# Out:
# [110574.          69298.91944161]
# [[110574.          69298.91944161]
#  [ 55287.          34649.45972081]]

# %% [markdown]
# Convert all coordinates to vectors in metres, using home as a reference

# %%
REFERENCE_XY = LOCATIONS["home"]

def to_xy(latlong):
    latlong = np.reshape(np.array(latlong), (-1, 2))
    return latlong_vec_to_meters(
        latlong[:, 0],
        latlong - REFERENCE_XY
    )

location_log.loc[:, ["x","y"]] = to_xy(location_log.loc[:, ["latitude", "longitude"]].to_numpy())

location_log
# Out:
#                               entity_id   latitude  longitude          x  \
# time
# 2022-05-06 03:15:07.110833  person.gaby  51.409610  -0.280304 -22.400039
# 2022-05-06 03:20:23.946649  person.gaby  51.409616  -0.280316 -21.736595
# 2022-05-06 03:24:58.453512  person.gaby  51.409622  -0.280314 -21.062094
# 2022-05-06 03:30:02.878928  person.gaby  51.409595  -0.280277 -24.113936
# 2022-05-06 03:38:07.624507  person.gaby  51.409629  -0.280312 -20.343363
# ...                                 ...        ...        ...        ...
# 2022-10-23 10:38:46.192274  person.gaby  51.409737  -0.280182  -8.368199
# 2022-10-23 10:43:17.976969  person.gaby  51.409736  -0.280219  -8.500887
# 2022-10-23 10:44:48.313036  person.gaby  51.409736  -0.280214  -8.489830
# 2022-10-23 10:46:18.302846  person.gaby  51.409742  -0.280145  -7.815329
# 2022-10-23 10:49:59.107114  person.gaby  51.409731  -0.280122  -9.053757
#
#                                    y place    dx    dy
# time
# 2022-05-06 03:15:07.110833 -9.025556  None  None  None
# 2022-05-06 03:20:23.946649 -9.831009  None  None  None
# 2022-05-06 03:24:58.453512 -9.719911  None  None  None
# 2022-05-06 03:30:02.878928 -7.171626  None  None  None
# 2022-05-06 03:38:07.624507 -9.587981  None  None  None
# ...                              ...   ...   ...   ...
# 2022-10-23 10:38:46.192274 -0.561345  None  None  None
# 2022-10-23 10:43:17.976969 -3.144345  None  None  None
# 2022-10-23 10:44:48.313036 -2.790224  None  None  None
# 2022-10-23 10:46:18.302846  2.056373  None  None  None
# 2022-10-23 10:49:59.107114  3.590898  None  None  None
#
# [42850 rows x 8 columns]

# %%
location_log.loc[:, ["dx","dy"]] = location_log.loc[:, ["x", "y"]].diff().to_numpy()
location_log
# Out:
#                               entity_id   latitude  longitude          x  \
# time
# 2022-05-06 03:15:07.110833  person.gaby  51.409610  -0.280304 -22.400039
# 2022-05-06 03:20:23.946649  person.gaby  51.409616  -0.280316 -21.736595
# 2022-05-06 03:24:58.453512  person.gaby  51.409622  -0.280314 -21.062094
# 2022-05-06 03:30:02.878928  person.gaby  51.409595  -0.280277 -24.113936
# 2022-05-06 03:38:07.624507  person.gaby  51.409629  -0.280312 -20.343363
# ...                                 ...        ...        ...        ...
# 2022-10-23 10:38:46.192274  person.gaby  51.409737  -0.280182  -8.368199
# 2022-10-23 10:43:17.976969  person.gaby  51.409736  -0.280219  -8.500887
# 2022-10-23 10:44:48.313036  person.gaby  51.409736  -0.280214  -8.489830
# 2022-10-23 10:46:18.302846  person.gaby  51.409742  -0.280145  -7.815329
# 2022-10-23 10:49:59.107114  person.gaby  51.409731  -0.280122  -9.053757
#
#                                    y place        dx        dy
# time
# 2022-05-06 03:15:07.110833 -9.025556  None       NaN       NaN
# 2022-05-06 03:20:23.946649 -9.831009  None  0.663444 -0.805453
# 2022-05-06 03:24:58.453512 -9.719911  None  0.674501  0.111098
# 2022-05-06 03:30:02.878928 -7.171626  None -3.051842  2.548285
# 2022-05-06 03:38:07.624507 -9.587981  None  3.770573 -2.416355
# ...                              ...   ...       ...       ...
# 2022-10-23 10:38:46.192274 -0.561345  None -0.176918  5.089621
# 2022-10-23 10:43:17.976969 -3.144345  None -0.132689 -2.583000
# 2022-10-23 10:44:48.313036 -2.790224  None  0.011057  0.354121
# 2022-10-23 10:46:18.302846  2.056373  None  0.674501  4.846597
# 2022-10-23 10:49:59.107114  3.590898  None -1.238429  1.534525
#
# [42850 rows x 8 columns]

# %%
location_log["place"] = None

for place_name, place_coords in LOCATIONS.items():
    place_xy = to_xy(place_coords)
    k_close = np.linalg.norm(location_log.loc[:, ["x", "y"]] - place_xy, axis=1) < RADIUS
    if any(location_log.loc[k_close, "place"].notna()):
        raise ValueError("Some locations are found twice")
    location_log.loc[k_close, "place"] = place_name
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [13], in <cell line: 4>()
#       2 location_log["dx"] = None
#       3 location_log["dy"] = None
# ----> 4 location_log.loc[:-1,"dx"] = location_log.loc[1:,"x"] - location_log.loc[:-1,"x"]
#       6 for place_name, place_coords in LOCATIONS.items():
#       7     place_xy = to_xy(place_coords)
#
# File /usr/local/lib/python3.9/dist-packages/pandas/core/indexing.py:925, in _LocationIndexer.__getitem__(self, key)
#     923         with suppress(KeyError, IndexError):
#     924             return self.obj._get_value(*key, takeable=self._takeable)
# --> 925     return self._getitem_tuple(key)
#     926 else:
#     927     # we by definition only have the 0th axis
#     928     axis = self.axis or 0
#
# File /usr/local/lib/python3.9/dist-packages/pandas/core/indexing.py:1100, in _LocIndexer._getitem_tuple(self, tup)
#    1098 def _getitem_tuple(self, tup: tuple):
#    1099     with suppress(IndexingError):
# -> 1100         return self._getitem_lowerdim(tup)
#    1102     # no multi-index, so validate all of the indexers
#    1103     self._has_valid_tuple(tup)
#
# File /usr/local/lib/python3.9/dist-packages/pandas/core/indexing.py:862, in _LocationIndexer._getitem_lowerdim(self, tup)
#     860             return section
#     861         # This is an elided recursive call to iloc/loc
# --> 862         return getattr(section, self.name)[new_key]
#     864 raise IndexingError("not applicable")
#
# File /usr/local/lib/python3.9/dist-packages/pandas/core/indexing.py:931, in _LocationIndexer.__getitem__(self, key)
#     928 axis = self.axis or 0
#     930 maybe_callable = com.apply_if_callable(key, self.obj)
# --> 931 return self._getitem_axis(maybe_callable, axis=axis)
#
# File /usr/local/lib/python3.9/dist-packages/pandas/core/indexing.py:1142, in _LocIndexer._getitem_axis(self, key, axis)
#    1140 if isinstance(key, slice):
#    1141     self._validate_key(key, axis)
# -> 1142     return self._get_slice_axis(key, axis=axis)
#    1143 elif com.is_bool_indexer(key):
#    1144     return self._getbool_axis(key, axis=axis)
#
# File /usr/local/lib/python3.9/dist-packages/pandas/core/indexing.py:1176, in _LocIndexer._get_slice_axis(self, slice_obj, axis)
#    1173     return obj.copy(deep=False)
#    1175 labels = obj._get_axis(axis)
# -> 1176 indexer = labels.slice_indexer(slice_obj.start, slice_obj.stop, slice_obj.step)
#    1178 if isinstance(indexer, slice):
#    1179     return self.obj._slice(indexer, axis=axis)
#
# File /usr/local/lib/python3.9/dist-packages/pandas/core/indexes/base.py:5685, in Index.slice_indexer(self, start, end, step, kind)
#    5639 def slice_indexer(
#    5640     self,
#    5641     start: Hashable | None = None,
#    (...)
#    5644     kind: str_t | None = None,
#    5645 ) -> slice:
#    5646     """
#    5647     Compute the slice indexer for input labels and step.
#    5648
#    (...)
#    5683     slice(1, 3, None)
#    5684     """
# -> 5685     start_slice, end_slice = self.slice_locs(start, end, step=step)
#    5687     # return a slice
#    5688     if not is_scalar(start_slice):
#
# File /usr/local/lib/python3.9/dist-packages/pandas/core/indexes/base.py:5887, in Index.slice_locs(self, start, end, step, kind)
#    5885 start_slice = None
#    5886 if start is not None:
# -> 5887     start_slice = self.get_slice_bound(start, "left")
#    5888 if start_slice is None:
#    5889     start_slice = 0
#
# File /usr/local/lib/python3.9/dist-packages/pandas/core/indexes/base.py:5797, in Index.get_slice_bound(self, label, side, kind)
#    5793 original_label = label
#    5795 # For datetime indices label may be a string that has to be converted
#    5796 # to datetime boundary according to its resolution.
# -> 5797 label = self._maybe_cast_slice_bound(label, side)
#    5799 # we need to look up the label
#    5800 try:
#
# File /usr/local/lib/python3.9/dist-packages/pandas/core/indexes/base.py:5749, in Index._maybe_cast_slice_bound(self, label, side, kind)
#    5744 # We are a plain index here (sub-class override this method if they
#    5745 # wish to have special treatment for floats/ints, e.g. Float64Index and
#    5746 # datetimelike Indexes
#    5747 # reject them, if index does not contain label
#    5748 if (is_float(label) or is_integer(label)) and label not in self._values:
# -> 5749     raise self._invalid_indexer("slice", label)
#    5751 return label
#
# TypeError: cannot do slice indexing on Index with these indexers [1] of type int

# %%
location_log["place"].unique()
# Out:
# array(['home', None, 'imperial', 'richmond_park', 'A3'], dtype=object)

# %%
plt.figure()
for place_name in LOCATIONS.keys():
    k = location_log["place"] == place_name
    plt.scatter(location_log.loc[k, "x"],location_log.loc[k, "y"])

plt.legend(LOCATIONS.keys());
