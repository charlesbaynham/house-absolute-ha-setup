# %% [markdown]
# # Messing around with location history

# %%
#!pip install HASS-data-detective # Install detective

# %%
# !pip install plotly chart-studio swifter

# %%
# !pip show HASS-data-detective

# %%
from typing import *
import pandas as pd
from sqlalchemy import create_engine, text
from detective.core import stripped_db_url, get_db_type

# Modify hass-data-detective
class HassDatabase:
    """
    Initializing the parser fetches all of the data from the database and
    places it in a master pandas dataframe.
    """

    def __init__(self, url, *, fetch_entities=True):
        """
        Parameters
        ----------
        url : str
            The URL to the database.
        """
        self.url = url
        self.entities = None
        try:
            self.engine = create_engine(url)
            print("Successfully connected to database", stripped_db_url(url))
            if fetch_entities:
                self.fetch_entities()
        except Exception as exc:
            if isinstance(exc, ImportError):
                raise RuntimeError(
                    "The right dependency to connect to your database is "
                    "missing. Please make sure that it is installed."
                )

            print(exc)
            raise

        self.db_type = get_db_type(url)

    def perform_query(self, query, **params):
        """Perform a query."""
        try:
            return self.engine.execute(query, params)
        except:
            print(f"Error with query: {query}")
            raise

    def fetch_entities(self) -> None:
        """Fetch entities for which we have data."""
        query = text(
            """
            SELECT DISTINCT(entity_id) FROM states
            """
        )
        response = self.perform_query(query)

        # Parse the domains from the entities.
        self.entities = [e[0] for e in response]
        print(f"There are {len(self.entities)} entities with data")

    def fetch_all_sensor_data(self, limit=50000, get_attributes=False) -> pd.DataFrame:
        """
        Fetch data for all sensor entities.

        Arguments:
        - limit (default: 50000): Limit the maximum number of state changes loaded.
            If None, there is no limit.
        - get_attributes: If True, LEFT JOIN the attributes table to retrieve event's attributes.
        """
        
        if get_attributes:
            query = """
                SELECT entity_id, state, last_updated, shared_attrs
            """
        else:
            query = """
                SELECT entity_id, state, last_updated
            """
        
        query += "FROM states"
        
        if get_attributes:
            query += """
                LEFT JOIN state_attributes ON states.attributes_id = state_attributes.attributes_id
            """
            
        query += """
            WHERE
                entity_id  LIKE '%sensor%'
            AND
                state NOT IN ('unknown', 'unavailable')
            ORDER BY last_updated DESC
            """
        
        if limit is not None:
            query += f"LIMIT {limit}"
        df = pd.read_sql_query(query, self.url)
        print(f"The returned Pandas dataframe has {df.shape[0]} rows of data.")
        return df

    def fetch_all_data_of(self, sensors: Tuple[str], limit=50000, get_attributes=False) -> pd.DataFrame:
        """
        Fetch data for sensors.

        Arguments:
        - limit (default: 50000): Limit the maximum number of state changes loaded.
            If None, there is no limit.
        - get_attributes: If True, LEFT JOIN the attributes table to retrieve event's attributes.
        """
        sensors_str = str(tuple(sensors))
        if len(sensors) == 1:
            sensors_str = sensors_str.replace(",", "")

        if get_attributes:
            query = """
                SELECT entity_id, state, last_updated, shared_attrs
            """
        else:
            query = """
                SELECT entity_id, state, last_updated
            """

        query += "FROM states"
        
        if get_attributes:
            query += """
                LEFT JOIN state_attributes ON states.attributes_id = state_attributes.attributes_id
            """
            
        query += f"""
            WHERE
                entity_id IN {sensors_str}
            AND
                state NOT IN ('unknown', 'unavailable')
            ORDER BY last_updated DESC
            """

        if limit is not None:
            query += f"LIMIT {limit}"
            
        df = pd.read_sql_query(query, self.url)
        print(f"The returned Pandas dataframe has {df.shape[0]} rows of data.")
        return df

# %%
import detective.config as config
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import swifter

def my_db_from_hass_config(path=None, **kwargs):
    """Initialize a database from HASS config."""
    if path is None:
        path = config.find_hass_config()

    url = config.db_url_from_hass_config(path)
    return HassDatabase(url, **kwargs)

db = my_db_from_hass_config(fetch_entities=False)
# Out:
# YAML tag !include_dir_merge_list is not supported
# YAML tag !include_dir_merge_named is not supported
# Successfully connected to database sqlite:////config/home-assistant_v2.db

# %% [markdown]
# First we extract all state changes for Gaby and Charles

# %%
people = ("person.charles","person.gaby",)

# %%
results = db.fetch_all_data_of(people, get_attributes=True)
results
# Out:
# The returned Pandas dataframe has 42850 rows of data.
#          entity_id state                last_updated  \
# 0      person.gaby  home  2022-10-23 10:49:59.107114
# 1      person.gaby  home  2022-10-23 10:46:18.302846
# 2      person.gaby  home  2022-10-23 10:44:48.313036
# 3      person.gaby  home  2022-10-23 10:43:17.976969
# 4      person.gaby  home  2022-10-23 10:38:46.192274
# ...            ...   ...                         ...
# 42845  person.gaby  home  2022-05-06 03:38:07.624507
# 42846  person.gaby  home  2022-05-06 03:30:02.878928
# 42847  person.gaby  home  2022-05-06 03:24:58.453512
# 42848  person.gaby  home  2022-05-06 03:20:23.946649
# 42849  person.gaby  home  2022-05-06 03:15:07.110833
#
#                                             shared_attrs
# 0      {"editable":false,"id":"gaby","latitude":51.40...
# 1      {"editable":false,"id":"gaby","latitude":51.40...
# 2      {"editable":false,"id":"gaby","latitude":51.40...
# 3      {"editable":false,"id":"gaby","latitude":51.40...
# 4      {"editable":false,"id":"gaby","latitude":51.40...
# ...                                                  ...
# 42845  {"editable":false,"id":"gaby","latitude":51.40...
# 42846  {"editable":false,"id":"gaby","latitude":51.40...
# 42847  {"editable":false,"id":"gaby","latitude":51.40...
# 42848  {"editable":false,"id":"gaby","latitude":51.40...
# 42849  {"editable":false,"id":"gaby","latitude":51.40...
#
# [42850 rows x 4 columns]

# %%
# Copied from HASS-data-detective and modified to join the new attributes table
sensors_str = str(tuple(people))
if len(people) == 1:
    sensors_str = sensors_str.replace(",", "")

query = f"""
    SELECT domain, entity_id, state, last_updated, shared_attrs
    FROM states
    LEFT JOIN state_attributes ON states.attributes_id = state_attributes.attributes_id
    WHERE
        entity_id IN {sensors_str}
    AND
        state NOT IN ('unknown', 'unavailable')
    ORDER BY last_changed DESC
    """

results = pd.read_sql_query(query, db.url)
print(f"{len(results)} results loaded")
results
# Out:
# 42850 results loaded
#       domain       entity_id state                last_updated  \
# 0       None  person.charles  home  2022-10-22 04:50:05.728112
# 1       None     person.gaby  home  2022-10-22 04:46:59.531755
# 2       None     person.gaby  home  2022-10-22 04:47:07.528203
# 3       None     person.gaby  home  2022-10-22 04:47:45.386224
# 4       None     person.gaby  home  2022-10-22 04:49:35.753061
# ...      ...             ...   ...                         ...
# 42845   None     person.gaby  home  2022-05-06 06:43:22.576767
# 42846   None     person.gaby  home  2022-05-06 06:46:22.767125
# 42847   None     person.gaby  home  2022-05-06 06:47:16.641555
# 42848   None     person.gaby  home  2022-05-06 06:47:34.924815
# 42849   None     person.gaby  home  2022-05-06 06:53:40.004542
#
#                                             shared_attrs
# 0      {"editable":false,"id":"charles","latitude":51...
# 1      {"editable":false,"id":"gaby","latitude":51.41...
# 2      {"editable":false,"id":"gaby","latitude":51.41...
# 3      {"editable":false,"id":"gaby","latitude":51.40...
# 4      {"editable":false,"id":"gaby","latitude":51.40...
# ...                                                  ...
# 42845  {"editable":false,"id":"gaby","latitude":51.40...
# 42846  {"editable":false,"id":"gaby","latitude":51.40...
# 42847  {"editable":false,"id":"gaby","latitude":51.40...
# 42848  {"editable":false,"id":"gaby","latitude":51.40...
# 42849  {"editable":false,"id":"gaby","latitude":51.40...
#
# [42850 rows x 5 columns]

# %%
results.last_changed = pd.to_datetime(results["last_updated"])
results.set_index('last_updated', inplace=True)
results.index.rename("time", inplace=True)
results.sort_index(inplace=True)
results
# Out:
# /tmp/ipykernel_999/2555479191.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   results.last_changed = pd.to_datetime(results["last_updated"])
#                            domain    entity_id state  \
# time
# 2022-05-06 03:15:07.110833   None  person.gaby  home
# 2022-05-06 03:20:23.946649   None  person.gaby  home
# 2022-05-06 03:24:58.453512   None  person.gaby  home
# 2022-05-06 03:30:02.878928   None  person.gaby  home
# 2022-05-06 03:38:07.624507   None  person.gaby  home
# ...                           ...          ...   ...
# 2022-10-23 10:38:46.192274   None  person.gaby  home
# 2022-10-23 10:43:17.976969   None  person.gaby  home
# 2022-10-23 10:44:48.313036   None  person.gaby  home
# 2022-10-23 10:46:18.302846   None  person.gaby  home
# 2022-10-23 10:49:59.107114   None  person.gaby  home
#
#                                                                  shared_attrs
# time
# 2022-05-06 03:15:07.110833  {"editable":false,"id":"gaby","latitude":51.40...
# 2022-05-06 03:20:23.946649  {"editable":false,"id":"gaby","latitude":51.40...
# 2022-05-06 03:24:58.453512  {"editable":false,"id":"gaby","latitude":51.40...
# 2022-05-06 03:30:02.878928  {"editable":false,"id":"gaby","latitude":51.40...
# 2022-05-06 03:38:07.624507  {"editable":false,"id":"gaby","latitude":51.40...
# ...                                                                       ...
# 2022-10-23 10:38:46.192274  {"editable":false,"id":"gaby","latitude":51.40...
# 2022-10-23 10:43:17.976969  {"editable":false,"id":"gaby","latitude":51.40...
# 2022-10-23 10:44:48.313036  {"editable":false,"id":"gaby","latitude":51.40...
# 2022-10-23 10:46:18.302846  {"editable":false,"id":"gaby","latitude":51.40...
# 2022-10-23 10:49:59.107114  {"editable":false,"id":"gaby","latitude":51.40...
#
# [42850 rows x 4 columns]

# %%
import yaml
l = lambda s : yaml.safe_load(s)
results["parsed_attrs"] = results.loc[:, "shared_attrs"].swifter.apply(l)
# Out:
# Pandas Apply:   0%|          | 0/42850 [00:00<?, ?it/s]

# %%
results['latitude'] = results['parsed_attrs'].apply(lambda i : i['latitude'])
results['longitude'] = results['parsed_attrs'].apply(lambda i : i['longitude'])

# %%
import matplotlib.pyplot as plt

for person in people:
    plt.figure()
    k = (results["entity_id"] == person) & (results["longitude"] > -20)
    plt.scatter(results.loc[k, 'longitude'], results.loc[k, 'latitude'])
    plt.legend([person])
# results.plot.scatter(x="longitude", y="latitude", alpha=0.4, label="entity_id");

# %%
out = results.loc[:,['entity_id', 'latitude', 'longitude']]
out
# Out:
#                               entity_id   latitude  longitude
# time
# 2022-05-06 03:15:07.110833  person.gaby  51.409610  -0.280304
# 2022-05-06 03:20:23.946649  person.gaby  51.409616  -0.280316
# 2022-05-06 03:24:58.453512  person.gaby  51.409622  -0.280314
# 2022-05-06 03:30:02.878928  person.gaby  51.409595  -0.280277
# 2022-05-06 03:38:07.624507  person.gaby  51.409629  -0.280312
# ...                                 ...        ...        ...
# 2022-10-23 10:38:46.192274  person.gaby  51.409737  -0.280182
# 2022-10-23 10:43:17.976969  person.gaby  51.409736  -0.280219
# 2022-10-23 10:44:48.313036  person.gaby  51.409736  -0.280214
# 2022-10-23 10:46:18.302846  person.gaby  51.409742  -0.280145
# 2022-10-23 10:49:59.107114  person.gaby  51.409731  -0.280122
#
# [42850 rows x 3 columns]

# %%
out.to_csv("locations.csv")

# %%
pd.read_csv("locations.csv")
# Out:
#                              time    entity_id   latitude  longitude
# 0      2022-05-06 03:15:07.110833  person.gaby  51.409610  -0.280304
# 1      2022-05-06 03:20:23.946649  person.gaby  51.409616  -0.280316
# 2      2022-05-06 03:24:58.453512  person.gaby  51.409622  -0.280314
# 3      2022-05-06 03:30:02.878928  person.gaby  51.409595  -0.280277
# 4      2022-05-06 03:38:07.624507  person.gaby  51.409629  -0.280312
# ...                           ...          ...        ...        ...
# 42845  2022-10-23 10:38:46.192274  person.gaby  51.409737  -0.280182
# 42846  2022-10-23 10:43:17.976969  person.gaby  51.409736  -0.280219
# 42847  2022-10-23 10:44:48.313036  person.gaby  51.409736  -0.280214
# 42848  2022-10-23 10:46:18.302846  person.gaby  51.409742  -0.280145
# 42849  2022-10-23 10:49:59.107114  person.gaby  51.409731  -0.280122
#
# [42850 rows x 4 columns]
